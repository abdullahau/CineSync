# %% [markdown]
# # 01 - Data Wrangling

# %% [markdown]
# ## Configuration (`config.yaml`)

# %% [markdown]
# ## Watchlist/Diary Import

# %% [markdown]
# ## Build a Custom Movies & TV Database

# %% [markdown]
# ### Schema

# %% [markdown]
# ![Schema ER Diagram](../src/cinesync/schemas/schema.svg)

# %% [markdown]
# Build database from `src/cinesync/schemas/schema.sql`
#
# ```bash
# uv run src/cinesync/init_db.py
# ```

# %% [markdown]
# ### Data Ingestion (API)

# %% [markdown]
# **TMDB**:
#
# Run inside a terminal multiplexer session:
# ```bash
# uv run --env-file .env notebooks/tmdb_ingest.py
# ```
#
# **Letterboxd Rating**:
#
# Run inside a terminal multiplexer session:
# ```bash
# uv run --env-file .env notebooks/letterboxd_ingest.py
# ```

# %% [markdown]
# **Database**:
# - Vote Count (>50) - Movies: 34102, TV: 6702
# - Rating (>6.5 with Vote Count >10) - Movies: 17372, TV: 8286
# - Lang Hindi - Movies: 1634, TV: 208
# - Lang Urdu - Movies: 402, TV: 549
# - Lang Korean - Movies: 552, TV: 297
# - Lang Japanese - Movies: 1446, TV: 588
