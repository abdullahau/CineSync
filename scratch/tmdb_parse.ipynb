# %%
from cinesync.ingestion.tmdb_parser import parse_tmdb_response
from cinesync.paths import DATA_DIR
import json

# %%
keys = ['title', 'genres', 'keywords', 'companies', 'credits', 'crew_extra', 'score']
MOVIE_DIR = DATA_DIR / "tmdb_detail_sample" / "movie"
TV_DIR = DATA_DIR / "tmdb_detail_sample" / "tv"

# %%
with open(MOVIE_DIR / "246.json", "r") as f:
    data = parse_tmdb_response(json.load(f), "movie")

for i in keys:
    print(i)
    print(data[i], "\n")
# Out:
# title
# {'title_id': 'movie_246', 'tmdb_id': 246, 'content_type': 'movie', 'name': 'Zatoichi', 'original_language': 'ja', 'release_year': 2003, 'runtime_minutes': 116, 'number_of_seasons': None, 'status': 'Released', 'imdb_id': 'tt0363226', 'wikidata_id': 'Q148330', 'overview': 'Blind traveler Zatoichi is a master swordsman and a masseur with a fondness for gambling on dice games. When he arrives in a village torn apart by warring gangs, he sets out to protect the townspeople.', 'detailed_plot': None, 'source': 'tmdb_discover'}
#
# genres
# ['Adventure', 'Drama', 'Action']
#
# keywords
# ['martial arts', 'japan', 'samurai', 'sword', 'geisha', 'blackmail', 'revenge', 'blind', 'jidaigeki', 'aggressive']
#
# companies
# ...

# %%
with open(MOVIE_DIR / "1083381.json", "r") as f:
    data = parse_tmdb_response(json.load(f), "movie")

for i in keys:
    print(i)
    print(data[i], "\n")
# Out:
# title
# {'title_id': 'movie_1083381', 'tmdb_id': 1083381, 'content_type': 'movie', 'name': 'Backrooms', 'original_language': 'en', 'release_year': 2026, 'runtime_minutes': 111, 'number_of_seasons': None, 'status': 'Released', 'imdb_id': 'tt26657236', 'wikidata_id': 'Q125131076', 'overview': 'A strange doorway appears in the basement of a furniture showroom.', 'detailed_plot': None, 'source': 'tmdb_discover'}
#
# genres
# ['Horror', 'Mystery', 'Science Fiction']
#
# keywords
# ['california', 'monster', 'therapist', 'surrealism', 'childhood trauma', 'alcoholism', 'found footage', '1990s', 'other dimension', 'based on web series', 'psychological', 'liminal', 'body horror', 'psychological horror', 'liminal space', 'analog horror', 'sci-fi horror', 'bewildered', 'foreboding', 'liminal horror']
#
# companies
# ...

# %%
with open(TV_DIR / "1396.json", "r") as f:
    data = parse_tmdb_response(json.load(f), "tv")

for i in keys:
    print(i)
    print(data[i], "\n")
# Out:
# title
# {'title_id': 'tv_1396', 'tmdb_id': 1396, 'content_type': 'tv', 'name': 'Breaking Bad', 'original_language': 'en', 'release_year': 2008, 'runtime_minutes': 56, 'number_of_seasons': 5, 'status': 'Ended', 'imdb_id': 'tt0903747', 'wikidata_id': 'Q1079', 'overview': "Walter White, a New Mexico chemistry teacher, is diagnosed with Stage III cancer and given a prognosis of only two years left to live. He becomes filled with a sense of fearlessness and an unrelenting desire to secure his family's financial future at any cost as he enters the dangerous world of drugs and crime.", 'detailed_plot': None, 'source': 'tmdb_discover'}
#
# genres
# ['Drama', 'Crime']
#
# keywords
# ...
